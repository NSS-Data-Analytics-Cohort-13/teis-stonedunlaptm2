# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.max_columns = None

# %%
pd.read_csv('../data/bdi2_scores.csv')
# Out:
# C:\Users\Michelle\AppData\Local\Temp\ipykernel_22668\4089583917.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('../data/bdi2_scores.csv')
#         StudentID  studentAssessmentID  resultStudentDomainID  \
# 0         2224693              8625078              138104116
# 1         2224693              8625078              138104117
# 2         2224693              8625078              138104118
# 3         2224693              8625078              138104119
# 4         2224693              8625078              138104120
# ...           ...                  ...                    ...
# 325681    2319431              8761874              140602545
# 325682    2319431              8761874              140602546
# 325683    2319431              8761874              140602547
# 325684    2319431              8761874              140602548
# 325685    2319431              8761874              140602549
#
# ...

# %%
bdi2=pd.read_csv('../data/bdi2_scores.csv')
# Out:
# C:\Users\Michelle\AppData\Local\Temp\ipykernel_22668\2851461607.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   bdi2=pd.read_csv('../data/bdi2_scores.csv')

# %%
bdi2
# Out:
#         StudentID  studentAssessmentID  resultStudentDomainID  \
# 0         2224693              8625078              138104116
# 1         2224693              8625078              138104117
# 2         2224693              8625078              138104118
# 3         2224693              8625078              138104119
# 4         2224693              8625078              138104120
# ...           ...                  ...                    ...
# 325681    2319431              8761874              140602545
# 325682    2319431              8761874              140602546
# 325683    2319431              8761874              140602547
# 325684    2319431              8761874              140602548
# 325685    2319431              8761874              140602549
#
#        Student TEIDS ID  domainID                     domainText  ScoreTypeID  \
# 0                 52101         7                      Self-Care          2.0
# ...

# %%
pd.read_csv('../data/bdi3_scores.csv')
# Out:
# C:\Users\Michelle\AppData\Local\Temp\ipykernel_22668\2952384090.py:1: DtypeWarning: Columns (9,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('../data/bdi3_scores.csv')
#        Last Name  First Name  Gender  Date of Birth  \
# 0            NaN         NaN     NaN            NaN
# 1            NaN         NaN     NaN            NaN
# 2            NaN         NaN     NaN            NaN
# 3            NaN         NaN     NaN            NaN
# 4            NaN         NaN     NaN            NaN
# ...          ...         ...     ...            ...
# 34974        NaN         NaN     NaN            NaN
# 34975        NaN         NaN     NaN            NaN
# 34976        NaN         NaN     NaN            NaN
# 34977        NaN         NaN     NaN            NaN
# 34978        NaN         NaN     NaN            NaN
#
#        Location - Root Level (PC)        Location - Root Level (AH)  \
# ...

# %%
bdi3=pd.read_csv('../data/bdi3_scores.csv')
# Out:
# C:\Users\Michelle\AppData\Local\Temp\ipykernel_22668\2429268705.py:1: DtypeWarning: Columns (9,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   bdi3=pd.read_csv('../data/bdi3_scores.csv')

# %%
bdi3.shape
# Out:
# (34979, 228)

# %%
pd.read_csv('../data/eco_data.csv')
# Out:
# C:\Users\Michelle\AppData\Local\Temp\ipykernel_22668\3229181453.py:1: DtypeWarning: Columns (89,93,94,95,98,102,106,107,108,109,110,128,129,136,139) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('../data/eco_data.csv')
#      DISTRICT  CHILD_ID  Child ID_ Assessement point ECO_Entry_DATE  \
# 0          GN    473991                          NaN       1/7/2020
# 1          GN    474186                          NaN      2/13/2020
# 2          ET    474575                          NaN      1/17/2020
# 3          NW    474623                          NaN      1/22/2019
# 4          SW    474848                          NaN       7/9/2021
# ...       ...       ...                          ...            ...
# 9994       SC    579717                          NaN            NaN
# 9995       SC    579729                          NaN            NaN
# 9996       ET    580243                          NaN            NaN
# ...

# %%
eco=pd.read_csv('../data/eco_data.csv')
# Out:
# C:\Users\Michelle\AppData\Local\Temp\ipykernel_22668\1303243260.py:1: DtypeWarning: Columns (89,93,94,95,98,102,106,107,108,109,110,128,129,136,139) have mixed types. Specify dtype option on import or set low_memory=False.
#   eco=pd.read_csv('../data/eco_data.csv')

# %%
eco.index
# Out:
# RangeIndex(start=0, stop=9999, step=1)

# %%
eco.shape
# Out:
# (9999, 152)

# %%
bdi3_entry = bdi3[['TEIDS Child ID' ,'Adaptive-Self Care Date of Testing']]

# %%
eco1 = eco[['CHILD_ID' ,'Initial IFSP Date','ECO_Entry_DATE','ECO_Exit_DATE']]

# %%
bdi2_entry = bdi2[['Student TEIDS ID' ,'testDate','lastUpdateDate']]

# %%
bdi3_entry = bdi3[['TEIDS Child ID' ,'Adaptive-Self Care Date of Testing']]
